# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("C:\\Users\\admin\\Downloads\\Dataset2.csv")

# Convert 'Date of Establishment' to datetime format, coercing errors to NaT
data['Date of Establishment'] = pd.to_datetime(data['Date of Establishment'], errors='coerce')

# Function to perform Selection Sort
def selection_sort(dataset, column, ascending=True):
    n = len(dataset)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if (dataset[column].iloc[j] < dataset[column].iloc[min_index]) if ascending else (dataset[column].iloc[j] > dataset[column].iloc[min_index]):
                min_index = j
        dataset.iloc[i], dataset.iloc[min_index] = dataset.iloc[min_index].copy(), dataset.iloc[i].copy()

# Choose the column to sort
column_to_sort = 'Date of Establishment'

# Sort the dataset in ascending order based on the chosen column
selection_sort(data, column_to_sort, ascending=True)

# Display the sorted dataset
print(data)
# Out:
#                   Settlement Name        Location       Province  \
# 0                       Alexandra    Johannesburg        Gauteng
# 1                       Gugulethu       Cape Town   Western Cape
# 2                      Kwazakhele  Port Elizabeth   Eastern Cape
# 3                     Khayelitsha       Cape Town   Western Cape
# 4                      Phola Park    Johannesburg        Gauteng
# 5             Winnie Mandela Park    Johannesburg        Gauteng
# 6                    Kennedy Road          Durban  KwaZulu-Natal
# 7                  Joe Slovo Park       Cape Town   Western Cape
# 8                     Mizamoyethu       Cape Town   Western Cape
# 9                   Masiphumelele       Cape Town   Western Cape
# 10                     Zandspruit    Johannesburg        Gauteng
# 11                     Embalenhle      Mpumalanga     Mpumalanga
# 12                      Diepsloot    Johannesburg        Gauteng
# 13                         Kanana          Soweto        Gauteng
# 14                   Freedom Park    Johannesburg        Gauteng
# 15                      Ramaphosa    Johannesburg        Gauteng
# 16                      Masakhane    Eastern Cape   Eastern Cape
# 17                      Kya Sands    Johannesburg        Gauteng
# 18                    KwaNdengezi          Durban  KwaZulu-Natal
# 19                     Siyathemba      Mpumalanga     Mpumalanga
# 20  Barberton Informal Settlement       Barberton     Mpumalanga
# 21    Nkandla Informal Settlement   KwaZulu-Natal  KwaZulu-Natal
# 22                      Ethembeni     East London   Eastern Cape
# 23                        Makhaza       Cape Town   Western Cape
# 24                     Matlhagame      North West     North West
# 25                         Dunoon       Cape Town   Western Cape
# 26                     Cato Crest          Durban  KwaZulu-Natal
# 27     Lawley Informal Settlement    Johannesburg        Gauteng
# 28                      Mkholombe  Port Shepstone  KwaZulu-Natal
# 29                     Chris Hani          Durban  KwaZulu-Natal
# 30                      Lindelani          Durban  KwaZulu-Natal
# 31                      Barcelona       Cape Town   Western Cape
# 32                        Langrug    Stellenbosch   Western Cape
# 33                       Enkanini       Cape Town   Western Cape
# 34                   Blikkiesdorp       Cape Town   Western Cape
# 35                     Silvertown          Durban  KwaZulu-Natal
# 36                     Driftsands       Cape Town   Western Cape
# 37    Tshwane Informal Settlement        Pretoria        Gauteng
# 38                       Vusimuzi    Johannesburg        Gauteng
# 39          Isipingo Transit Camp          Durban  KwaZulu-Natal
# 40                Sweet Home Farm       Cape Town   Western Cape
# 41                   Mshenguville        Pretoria        Gauteng
# 42            Thabo Mbeki Village        Pretoria        Gauteng
# 43                   Plastic View        Pretoria        Gauteng
# 44            Marikana Settlement        Pretoria        Gauteng
#
#    Date of Establishment  Initial Population Current Population  \
# 0             1912-01-01                 100             179624
# 1             1958-01-01                 100            Unknown
# 2             1965-01-01                 100            Unknown
# 3             1983-01-01                 100             391749
# 4             1985-01-01                 100            Unknown
# 5             1990-01-01                 100            Unknown
# 6                    NaT                 100            Unknown
# 7             1990-01-01                 100            Unknown
# 8             1991-01-01                 100            Unknown
# 9             1992-01-01                 100              38000
# 10            1994-01-01                 100              70000
# 11            1994-01-01                 100            Unknown
# 12            1995-01-01                 100             138329
# 13            1996-01-01                 100            Unknown
# 14            1997-01-01                 100            Unknown
# 15            1998-01-01                 100            Unknown
# 16            1998-01-01                 100            Unknown
# 17            1999-01-01                 100            Unknown
# 18            1999-01-01                 100            Unknown
# 19            2000-01-01                 100            Unknown
# 20            2000-01-01                 100            Unknown
# 21                   NaT                 100            Unknown
# 22            2000-01-01                 100            Unknown
# 23            2001-01-01                 100            Unknown
# 24            2001-01-01                 100            Unknown
# 25            2001-01-01                 100              46891
# 26            2002-01-01                 100            Unknown
# 27            2004-01-01                 100            Unknown
# 28            2004-01-01                 100            Unknown
# 29            2005-01-01                 100            Unknown
# 30            2005-01-01                 100              50000
# 31            2005-01-01                 100            Unknown
# 32            2006-01-01                 100            Unknown
# 33            2006-01-01                 100            Unknown
# 34            2007-01-01                 100              20000
# 35            2007-01-01                 100            Unknown
# 36            2007-01-01                 100            Unknown
# 37            2008-01-01                 100            Unknown
# 38            2008-01-01                 100            Unknown
# 39            2009-01-01                 100            Unknown
# 40            2010-01-01                 100            Unknown
# 41            2010-01-01                 100            Unknown
# 42            2012-01-01                 100            Unknown
# 43            2013-01-01                 100            Unknown
# 44            2014-01-01                 100            Unknown
#
#    Environmental Hazards Socio-Economic Factors        Community Initiatives  \
# 0     Air quality issues       High crime rates               Youth programs
# 1          Air pollution      High unemployment      Skill training programs
# 2     Air quality issues           Low literacy      Adult education classes
# 3               Flooding      High unemployment    Community health programs
# 4               Flooding            Poor health    Community clean-up drives
# 5               Flooding       High crime rates           Crime watch groups
# 6           Fire hazards           Unemployment             Self-help groups
# 7           Fire hazards           Low literacy      Adult education classes
# 8           Fire hazards                Poverty   Health awareness campaigns
# 9    Water contamination                Poverty     Microfinance initiatives
# 10          Fire hazards       High crime rates    Youth mentorship programs
# 11   Water contamination           High poverty   Health awareness campaigns
# 12             Pollution                Poverty  Skill development workshops
# 13              Flooding           Low literacy      Adult education classes
# 14    Air quality issues           Low literacy      Adult education classes
# 15         Air pollution       High crime rates           Crime watch groups
# 16              Flooding      High unemployment        Job creation programs
# 17          Fire hazards             Low income     Microfinance initiatives
# 18          Fire hazards      High unemployment        Job training programs
# 19               Erosion      High unemployment        Job creation programs
# 20   Water contamination     High disease rates   Health awareness campaigns
# 21          Fire hazards                Poverty     Community savings groups
# 22   Water contamination      High unemployment        Job creation programs
# 23   Water contamination      High unemployment      Skill training programs
# 24          Fire hazards           Low literacy      Adult education classes
# 25       Sewage overflow            Poor health    Community clean-up drives
# 26          Fire hazards           Unemployment                    Job fairs
# 27   Water contamination           Low literacy      Adult education classes
# 28               Erosion     High disease rates   Health awareness campaigns
# 29               Erosion      High unemployment        Job training programs
# 30              Flooding             Low income     Community savings groups
# 31          Fire hazards     High disease rates   Health awareness campaigns
# 32          Fire hazards           Low literacy      Adult education classes
# 33          Fire hazards                Poverty      Skill training programs
# 34              Flooding           High poverty        Job training programs
# 35          Fire hazards       High crime rates           Crime watch groups
# 36   Water contamination             Low income      Skill training programs
# 37       Sewage overflow           High poverty   Health awareness campaigns
# 38   Water contamination           Unemployment                    Job fairs
# 39               Erosion           High poverty     Community savings groups
# 40         Air pollution       High crime rates           Crime watch groups
# 41               Erosion     High disease rates   Health awareness campaigns
# 42          Fire hazards           Job scarcity     Microfinance initiatives
# 43               Erosion           Job scarcity     Microfinance initiatives
# 44               Erosion           Job scarcity     Microfinance initiatives
#
#    NGO Involvement         Government Support             Key Challenges  \
# 0           Active     Urban renewal projects               Unemployment
# 1           Active              Urban renewal               Overcrowding
# 2           Active              Urban renewal             Service issues
# 3           Active         Subsidized housing                      Crime
# 4          Limited        Housing initiatives               Overcrowding
# 5           Active         Community policing                      Crime
# 6           Active           Housing projects          Housing struggles
# 7           Active         Rehousing projects           Lack of services
# 8          Limited         Rehousing projects               Fire hazards
# 9           Active          Emergency housing               Fire hazards
# 10          Active       Periodic demolitions    Infrastructure problems
# 11         Limited          Community support               Unemployment
# 12         Limited    Infrastructure upgrades               Overcrowding
# 13         Limited        Housing initiatives               Overcrowding
# 14         Limited              Urban renewal              Poor services
# 15          Active         Community policing                      Crime
# 16         Limited  Local government projects           Lack of services
# 17          Active       Fire safety programs               Fire hazards
# 18         Limited         Community advocacy  Service delivery protests
# 19         Limited          Community support               Unemployment
# 20         Limited   Electrification projects        Illegal connections
# 21         Limited          Community support           Lack of services
# 22          Active          Community support          High unemployment
# 23          Active       Water supply project             Water scarcity
# 24          Active          Community support     Lack of infrastructure
# 25          Active     Sanitation improvement          Sanitation issues
# 26          Active        Land regularization         Community activism
# 27         Limited         Rehousing projects         Inadequate housing
# 28         Limited        Land regularization         Land tenure issues
# 29          Active         Community projects        Poor infrastructure
# 30         Limited    Land tenure initiatives         Inadequate housing
# 31         Limited       Fire safety programs               Fire hazards
# 32         Limited      Community initiatives     Poor living conditions
# 33         Limited     Sanitation improvement         Lack of sanitation
# 34          Active       Temporary relocation                      Crime
# 35          Active         Community policing                      Crime
# 36          Active    Infrastructure projects               High-density
# 37          Active     Sanitation improvement          Sanitation issues
# 38          Active     Flood control projects             Flooding risks
# 39         Limited      Community initiatives          Temporary housing
# 40          Active         Community policing                      Crime
# 41         Limited     Sanitation improvement          Sanitation issues
# 42          Active      Job creation programs               Unemployment
# 43          Active              Legal support           Eviction threats
# 44         Limited        Land regularization           Lack of services
#
#              Recent Developments
# 0           New community center
# 1            New training center
# 2       New educational programs
# 3              Improved policing
# 4              New housing units
# 5    Improved community security
# 6        Land tenure initiatives
# 7            Improved sanitation
# 8           New housing projects
# 9               New water system
# 10      New fire safety measures
# 11           New health services
# 12             New housing units
# 13          New community school
# 14      New educational programs
# 15       Improved infrastructure
# 16           New job initiatives
# 17          Improved fire safety
# 18       New job training center
# 19           New job initiatives
# 20             New health clinic
# 21     New community initiatives
# 22           New job initiatives
# 23           New training center
# 24      New educational programs
# 25              New sewer system
# 26                New job center
# 27          New community school
# 28             New health clinic
# 29       New job training center
# 30            New flood defenses
# 31             New fire stations
# 32      New educational programs
# 33          New housing projects
# 34             Improved security
# 35             Improved security
# 36              New water system
# 37           New health services
# 38             New water filters
# 39  New community support center
# 40       Improved infrastructure
# 41        New health initiatives
# 42                New job center
# 43        New legal aid services
# 44                New job center
